# %% [markdown]
# # Primeros pasos con Python

# %% [markdown]
# ## Ejecucion de comandos de Linux en Google Colab

# %%
# Luego

# %%
# de muchas

# %%
# lineas de

# %%
# codigo

# %% [markdown]
# ## Definicion de variables

# %%
# Canales de Atencion
# 971 683 282

# %%
# Variables basicas : int, float, str , bool

# %%
var_entera = 12
var_punto_flotante = 9.81
var_cadena_caracter = "Primera Clase"
otra_var_cad_caracter = 'Que fea clase'
var_logica = False
otra_var_logica = True

# %%
# Variables son de naturaleza numerica (int,float) , entonces
# las 4 operaciones aritmeticas son muy naturales
x = var_entera +  23

# %%
x
# Out:
# 35

# %%
x + 99
# Out:
# 134

# %%
# Operaciones aritmeticas : + - * /
# Algoritmos de Euclides : D = d * q +r
# En python :
  # q = D // d
  # r = D % d

# Dados dos variables de tipo entero
D = 2025
d = 1982

# %%
q = D // d
q
# Out:
# 1

# %%
r = D % d
r
# Out:
# 43

# %%
# En los nombres de variables , no debe haber espacios en blanco

# los nombres de variables, no inician con caracteres numericos

# En los nombres de variables no poseen el caracter / (\)

# En los nombres de variables, no debe contener caracteres compuestos (caracteres tildados, dieresis, eñe)

# Nombre de las variables debe estar en concordancia con el uso que va tener
