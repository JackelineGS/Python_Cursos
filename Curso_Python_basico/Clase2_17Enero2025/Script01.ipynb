# %% [markdown]
# # Variables basicas de Python
# * int
# * float
# * str
# * bool

# %%
# Para variables de naturaleza numerica : + - * / **
# Numeros Enteros (Algoritmo de Euclides) : D = d * q +r
  # q = D // d
  # r = D % d

x1 = 12.5
x2 = 36

y1 = ((x1 + x2)**(x2 - 0.5*x1)) / (128 % x2)
y1
# Out:
# 7.075982134902473e+48

# %%
# Algunas reglas para la deficion de variables :
  # No deben contener espacios en blanco
  # No deben de contener caracteres compuestos
  # No deben de contener los caracteres / o \

# %%
# Numeros de tipo float : parte entera y mantisa (parte decimal)
  # float : Numeros punto flotante de precision doble

# %% [markdown]
# # Modulo matematico

# %%
# Carguemos el modulo matematico
import math as m

# %%
# Documentacion del modulo math
help(m)

# %%
# Funcion dir
dir(m)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# Documentacion de la funcion pow
help(m.pow)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
# Documentacion de la funcion trunc
help(m.trunc)
# Out:
# Help on built-in function trunc in module math:
#
# trunc(x, /)
#     Truncates the Real x to the nearest Integral toward 0.
#
#     Uses the __trunc__ magic method.

# %% [markdown]
# # El modulo random

# %%
# Carguemos el modulo
import random as rnd

# %%
# Documentacion del modulo random
help(rnd)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
# Lista de elementos que componen al modulo random  (alias : rnd)
# Funcion dir
dir(rnd)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
# Documentacion de la funcion gauss
help(rnd.gauss)
# Out:
# Help on method gauss in module random:
#
# gauss(mu=0.0, sigma=1.0) method of random.Random instance
#     Gaussian distribution.
#
#     mu is the mean, and sigma is the standard deviation.  This is
#     slightly faster than the normalvariate() function.
#
#     Not thread-safe without a lock around calls.

# %%
# Ejemplito
r1 = rnd.gauss()
r1

# 0.9544236943595441
# -1.5774769056266673
# -1.0674152985151446
# Out:
# -1.0674152985151446

# %%
# Documentacion de la funcion weibullvariate
help(rnd.weibullvariate)
# Out:
# Help on method weibullvariate in module random:
#
# weibullvariate(alpha, beta) method of random.Random instance
#     Weibull distribution.
#
#     alpha is the scale parameter and beta is the shape parameter.
