# %%
# Carga de modulos
import math as m
import random as rnd

# %%
rx = rnd.gauss()

# %%
rx
# Out:
# 0.09627320207956473

# %% [markdown]
# # Tareita
#   * Leer toda la documentacion del modulo math y de los elementos que lo componen
#   * Leer toda la documentacion del modulo random y  de los elementos que lo componen

# %% [markdown]
# # Datos o variables de naturaleza booleana
#
# * True
# * False

# %%
# Operadores de comparacion numerica
  # > < >= <= == =!

x1 = 12 < 19
x1
# Out:
# True

# %%
x2 = 245.9 >= 0.66**(-2.5)
x2
# Out:
# True

# %%
# and : y logico
# or : o logico
# not : operador negacion

# %%
#
x3 = True and False
x3
# Out:
# False

# %%
#
x4 = False and True
x4
# Out:
# False

# %%
x5 = (True and False) or (False or True)
x5
# Out:
# True

# %%
x6 = not x5
x6
# Out:
# False

# %% [markdown]
# ## Dualidad de True y False

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
True + (False/True)
# Out:
# 1.0

# %% [markdown]
# # Variables de tipo cadena de caracter

# %%
# Definicion de variables de tipo cadena de caracter
c1 = "Segunda Clase"
c2 = 'Programacion en python'

# %%
c1
# Out:
# 'Segunda Clase'

# %%
c2
# Out:
# 'Programacion en python'

# %%
c3 = "Profesor : 'Abraham Zamudio'"
c3
# Out:
# "Profesor : 'Abraham Zamudio'"

# %%
c4 = 'Profesor : "Abraham Zamudio"'
c4
# Out:
# 'Profesor : "Abraham Zamudio"'

# %% [markdown]
# ## Operacion de concatenacion

# %%
# + : str x str -> str
c1 + c2
# Out:
# 'Segunda ClaseProgramacion en python'

# %%
c1 + " " + c2
# Out:
# 'Segunda Clase Programacion en python'

# %% [markdown]
# ## Operacion de repeticion

# %%
# * : int x str -> str
# * : str * int -> str
c5 = ( 2 * c1 ) + (c2*3)
c5
# Out:
# 'Segunda ClaseSegunda ClaseProgramacion en pythonProgramacion en pythonProgramacion en python'

# %% [markdown]
# ## Acceso a los elementos que componen a una varible str

# %%
c1
# Out:
# 'Segunda Clase'

# %%
# En python, los indices inician en cero

# %%
# Segundo caracter de c1 : indice 1
c1[1]
# Out:
# 'e'

# %%
# Octavo caracter de c1
c1[7]
# Out:
# ' '

# %%
# Quinto caracter de c2
c2[4]
# Out:
# 'r'

# %%
# Ultimo caracter de c3
c3[-1]
# Out:
# "'"

# %%
# Penultimo caracter de c3
c3[-2]
# Out:
# 'o'

# %%
# Modulo string
import string

# %%
# Documentacion del modulo string
help(string)
# Out:
# Help on module string:
#
# NAME
#     string - A collection of string constants.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/string.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Public module variables:
#
#     whitespace -- a string containing all ASCII whitespace
#     ascii_lowercase -- a string containing all ASCII lowercase letters
#     ascii_uppercase -- a string containing all ASCII uppercase letters
#     ascii_letters -- a string containing all ASCII letters
#     digits -- a string containing all ASCII decimal digits
#     hexdigits -- a string containing all ASCII hexadecimal digits
#     octdigits -- a string containing all ASCII octal digits
# ...

# %%
# Elementos que componen al modulo string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
# # Elementos de interes del modulo string
# 'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace'

# %%
# Documentacion de ascii_letters
help(string.ascii_letters)
# Out:
# No Python documentation found for 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# quinto elemento de ascii_letters
letras = string.ascii_letters
letras[4]
# Out:
# 'e'

# %%
# Acceso a porciones de una variable de tipo cadena de caracter
# Accedamos a los ultimos 3 elementos de la variable letras
letras[-3:]
# Out:
# 'XYZ'

# %%
# Ultimos 5 elementos de c5
c5[-5:]
# Out:
# 'ython'

# %%
# Primeros 7 elementos de c3
c3[:6+1]
# Out:
# 'Profeso'

# %%
# Primeros 13 elementos de c5
c5[:12+1]
# Out:
# 'Segunda Clase'
